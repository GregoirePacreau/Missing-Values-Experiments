# %% [markdown]
# # Experiments on contamination for real datasets

# %%
import numpy
#import torch
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import pandas as pd

tex_fonts = {
    # Use LaTeX to write all text
    "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 10,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 8,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8
}
plt.rcParams.update(tex_fonts)

import seaborn as sns

from source.real_experiment import test_estimators, test_estimators_heatmap
from source.auxiliary_functions import remove_outliers_DDC, apply_estimator

from source.real_experiment import clean_cameras, clean_countries, clean_wine, clean_intdef, clean_kielmc,\
                                clean_htv, clean_ceosal, clean_attend, clean_barium, clean_breast_cancer

# %% [markdown]
# # Wooldridge datasets

# %%
test_estimators(clean_attend)
# Out:
# dim :  8
# nsamples :  680
# erank :  1.9931770661263968
# Erreur dans solve.default(cov, ...) :
#   le système est numériquement singulier : conditionnement de la réciproque = 1.70363e-16
# Appels : DI ... iDDC9I.O.Wrap.RR -> RR -> mahalanobis -> solve -> solve.default
# Exécution arrêtée
#            DDC MV 99 DDC MV 95 DDC II 99 DDC KNN 99      TSGS    DI
# classical    0.12362  0.129199  0.053497   0.045269  0.525324  None
# DDC MV 99          -  0.032988  0.170204   0.098002  0.489305  None
# DDC MV 95          -         -  0.175053   0.102502  0.500188  None
# DDC II 99          -         -         -   0.077892  0.544392  None
# DDC KNN 99         -         -         -          -  0.512982  None
# TSGS               -         -         -          -         -  None

# %%
sns.heatmap(test_estimators_heatmap(clean_attend)*100, annot=True)
plt.savefig('heatmap_attend.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Erreur dans solve.default(cov, ...) :
#   le système est numériquement singulier : conditionnement de la réciproque = 1.70363e-16
# Appels : DI ... iDDC9I.O.Wrap.RR -> RR -> mahalanobis -> solve -> solve.default
# Exécution arrêtée

# %%
test_estimators(clean_barium)
# Out:
# dim :  11
# nsamples :  131
# erank :  2.4094320179138835
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#            DDC MV 99 DDC MV 95 DDC II 99 DDC KNN 99      TSGS        DI
# classical   0.096163  0.149886  0.037524   0.079086  0.252559  0.254007
# DDC MV 99          -  0.062676  0.070686   0.037126  0.249405  0.218297
# DDC MV 95          -         -   0.12583   0.090815  0.285306  0.197207
# DDC II 99          -         -         -   0.049446  0.232008  0.230363
# DDC KNN 99         -         -         -          -  0.232307  0.216968
# TSGS               -         -         -          -         -  0.354486

# %%
sns.heatmap(test_estimators_heatmap(clean_barium)*100, annot=True)
plt.savefig('heatmap_barium.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...

# %%
test_estimators(clean_ceosal)
# Out:
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# dim :  13
# nsamples :  177
# erank :  2.4864198467731016
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Erreur dans solve.default(cov, ...) :
#   Routine Lapack dgesv : le système est exactement singulier : U[2,2] = 0
# Appels : TSGS -> gy.filt -> mahalanobis -> solve -> solve.default
# Exécution arrêtée
# Erreur dans solve.default(cov, ...) :
#   le système est numériquement singulier : conditionnement de la réciproque = 4.29854e-17
# Appels : DI ... iDDC9I.O.Wrap.RR -> RR -> mahalanobis -> solve -> solve.default
# Exécution arrêtée
#            DDC MV 99 DDC MV 95 DDC II 99 DDC KNN 99  TSGS    DI
# ...

# %%
sns.heatmap(test_estimators_heatmap(clean_ceosal)*100, annot=True)
plt.savefig('heatmap_ceosal.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Erreur dans solve.default(cov, ...) :
#   Routine Lapack dgesv : le système est exactement singulier : U[2,2] = 0
# Appels : TSGS -> gy.filt -> mahalanobis -> solve -> solve.default
# Exécution arrêtée
# Erreur dans solve.default(cov, ...) :
#   le système est numériquement singulier : conditionnement de la réciproque = 4.29854e-17
# Appels : DI ... iDDC9I.O.Wrap.RR -> RR -> mahalanobis -> solve -> solve.default
# Exécution arrêtée

# %%
test_estimators(clean_intdef)
# Out:
# dim :  12
# nsamples :  49
# erank :  2.1985290723311928
#            DDC MV 99 DDC MV 95 DDC II 99 DDC KNN 99      TSGS        DI
# classical   0.266744  0.281447   0.15319   0.243399  0.433231  0.497814
# DDC MV 99          -  0.055024  0.162893   0.054166  0.373569  0.468259
# DDC MV 95          -         -  0.178498   0.071083  0.363743  0.461588
# DDC II 99          -         -         -   0.168379  0.386597  0.463161
# DDC KNN 99         -         -         -          -  0.364481  0.451939
# TSGS               -         -         -          -         -  0.207166

# %%
sns.heatmap(test_estimators_heatmap(clean_intdef)*100, annot=True)
plt.savefig('heatmap_intdef.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
test_estimators(clean_kielmc)
# Out:
# dim :  19
# erank :  1.9637279538597967
#
#  The final data set we will analyze has 321 rows and 17 columns.
#
#
#  The final data set we will analyze has 321 rows and 17 columns.
#
#
#  The final data set we will analyze has 321 rows and 17 columns.
#
#
#  The final data set we will analyze has 321 rows and 17 columns.
# Erreur dans solve.default(cov, ...) :
#   le système est numériquement singulier : conditionnement de la réciproque = 0
# Appels : TSGS -> gy.filt -> mahalanobis -> solve -> solve.default
# Exécution arrêtée
#
#  The final data set we will analyze has 321 rows and 16 columns.
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %% [markdown]
# ### cameras

# %%
test_estimators(clean_cameras)
# Out:
# dim :  11
# nsamples :  1038
# erank :  2.6642557476264743
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#            DDC MV 99 DDC MV 95 DDC II 99 DDC KNN 99      TSGS        DI
# classical   0.325045  0.332515  0.295164   0.300023  0.901213  0.937225
# DDC MV 99          -  0.031313  0.119332   0.116628  0.881385  0.909653
# DDC MV 95          -         -  0.121779   0.120477   0.89273  0.919668
# DDC II 99          -         -         -   0.037916  0.881491  0.916379
# DDC KNN 99         -         -         -          -  0.879468  0.914339
# TSGS               -         -         -          -         -  0.334912

# %%
sns.heatmap(test_estimators_heatmap(clean_cameras)*100, annot=True)
plt.savefig('heatmap_cameras.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %% [markdown]
# ### countries

# %%
test_estimators(clean_countries)

# %% [markdown]
# ### Wine

# %%
test_estimators(clean_wine).to_latex()
# Out:
# dim :  13
# erank :  2.7625188438027544
# /var/folders/m2/86ygsxzd7m79qj2clmkdp7840000gn/T/ipykernel_24753/1402790253.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   test_estimators(clean_wine).to_latex()
# ...

# %%
sns.heatmap(test_estimators_heatmap(clean_wine)*100, annot=True)
plt.savefig('heatmap_wine.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Breast Cancer

# %%
test_estimators(clean_breast_cancer)
# Out:
# dim :  30
# erank :  2.25876269783779
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#            DDC MV 99 DDC MV 95 DDC II 99 DDC KNN 99      TSGS        DI
# classical   0.498042   0.51448  0.410405   0.432624  0.426112  0.814246
# DDC MV 99          -  0.048251  0.182715   0.118333  0.155071  0.634821
# DDC MV 95          -         -  0.212685   0.151331  0.180541  0.624027
# DDC II 99          -         -         -   0.106276  0.124347  0.671378
# DDC KNN 99         -         -         -          -   0.07009  0.675107
# TSGS               -         -         -          -         -  0.683039

# %%
sns.heatmap(test_estimators_heatmap(clean_breast_cancer)*100, annot=True)
plt.savefig('heatmap_breast_cancer.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /Users/gregoirepacreau/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
